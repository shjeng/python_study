# %% [markdown]
# #### 문제를 풀며 가장 자연스럽게 익숙해지는 파이썬 기본: 데이터 구조 - 리스트1

# %%
location = ['서울시', '경기도', '인천시']

# %%
print(location)
# Out:
# ['서울시', '경기도', '인천시']

# %%
location.append('부산시')  # 리스트에 '부산시' 추가, 'text1', 'text2' 등과 같이 연속으로 넣는 것은 불가능함.

# %%
location
# Out:
# ['서울시', '경기도', '인천시', '부산시']

# %%
location.append('대전시')  # 리스트에 '대전시' 추가
location.insert(1, '대구시')  # 리스트 두 번째에 '대구시' 추가

# %%
location
# Out:
# ['서울시', '경기도', '인천시', '부산시', '대전시']

# %%
location[0]  # 리스트 첫 번째 요소
location[1:3]  # 리스트 두 번째부터 세 번째 요소까지
# Out:
# ['경기도', '인천시']

# %%
location.remove('대전시')  # 리스트에서 '경기도' 제거, 없으면 오류
del location[0];  # 리스트 첫 번째 요소 제거
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 location.remove('대전시') # 리스트에서 '경기도' 제거, 없으면 오류
#       2 #del location[0]; # 리스트 첫 번째 요소 제거
#
# ValueError: list.remove(x): x not in list

# %%
location = list();  # 리스트 초기화
# [] 또는 list()로 초기화 가능

# %% [markdown]
# #### 리스트 변수
# 1. 리스트 선언
# ```
#     - 리스트 변수 = [] 또는 list()
# ```
# 2. 리스트 추가
# ```
#     - 리스트 변수.append(요소) # 리스트 끝에 요소 추가
#     - 리스트 변수.insert(인덱스, 요소) # 리스트 특정 위치에 요소 추가
# ```
# 3. 리스트 요소 삭제
# ```
#     - 리스트변수.remove(요소) # 리스트에서 요소 제거, 없으면 오류
#     - del 리스트변수[인덱스] # 리스트 특정 위치 요소 제거
# ```
# 4. 리스트 요소 수정
# ```
#     - 리스트변수[인덱스] = 새로운요소 # 리스트 특정 위치 요소 수정
# ```

# %%
location
# Out:
# ['서울시', '경기도', '인천시']

# %%
location = ['서울시', '경기도', '인천시', 1, 2.1, True]  # 리스트 선언

# %%
location
# Out:
# ['서울시', '경기도', '인천시', 1, 2.1, True]

# %% [markdown]
# #### 리스트 정렬

# %%
digit_set = [1, 5, 3, 2, 4]  # 숫자 리스트 선언

# %%
digit_set.sort() # 리스트 오름차순 정렬

# %%
digit_set
# Out:
# [1, 2, 3, 4, 5]

# %%
digit_set.reverse() # 리스트 내림차순 정렬

# %%
digit_set
# Out:
# [5, 4, 3, 2, 1]

# %%
python_is_easy = "python is easy"  # 문자열 선언, 아래 함수가 실행돼도 문자열은 변경되지 않음.
string_list = python_is_easy.split() # 문자열을 공백 기준으로 분리하여 리스트로 변환,
# Out:
# ['python', 'is', 'easy']

# %% [markdown]
# #### 18. 조건문

# %%
age = input("나이는?");
age_digit = int(age);
print (age_digit);
if(age_digit >= 19): # 괄호가 없어도 if문이 작동함.
    print("당신은 성인입니다.")
else:
    print("당신은 미성년자입니다.")

if age_digit < 19 and age_digit < 40: # or: 또는, and: 그리고
    print("당신은 청년입니다.")
if not age_digit < 40:
    print('40 미만이 아니다.')
# Out:
# 1
# 당신은 미성년자입니다.

# %% [markdown]
# #### 21. 문자열, 리스트, 조건문 활용 1

# %%
# 타입 출력
data1 = 10
data2 = 2.2
data3 = "fun-coding"
print(type(data1), type(data2), type(data3))  # 변수 타입 출력
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
# 기본 자료형
code = "000660\n0000102\t123123123\n"
print(code)  # 문자열 출력
# Out:
# 000660
# 0000102	123123123

# %%
# 삼항연산자
data1 = 10
result = "성공" if data1 > 5 else "실패"  # 조건에 따라 다른 값을 할당
data1 = 'test-2'
# data1.replace('-', '_')  # 문자열에서 '-'를 '_'로 변경

# %%
# strip 함수
data1 = "  te.......st-2  ........"
data1 = data1.strip()  # 문자열 양쪽 공백 제거
print(data1)
data1 = ' ad2############ad '
data1 = data1.strip(' ad')
print(data1)
# Out:
# te.......st-2  ........
# 2############

# %%
# 문자열 찾기
data = 'find str'
index = data.find('find') # find 함수는 문자열에서 특정 문자열의 시작 인덱스를 반환, 없으면 -1 반환
print(index)
# Out:
# 0

# %%
data = 'ad ad ad ad ad ad count6'
count = data.count('ad')  # count 함수는 문자열에서 특정 문자열의 개수를 반환
print(count)
# Out:
# 6

# %%
i = 0;
while i <= 3:
    print(i)
    i += 1
text = 'test-2'
text2 = 'test-2'
text.__eq__('test-2')  # 문자열 비교, True 반환
print("==")
text == text2
print(text is text2)
# Out:
# 0
# 1
# 2
# 3
# ==
# False

# %% [markdown]
# #### 27. 함수 익히기 1 : https://www.inflearn.com/courses/lecture?courseId=324082&type=LECTURE&unitId=21255&tab=curriculum

# %%
def func1(parameter, parameter2) :
    print("hello!", parameter, parameter2)

# %%
func1('Python', 'JAVA')  # 함수 호출, 인자 전달
# Out:
# hello! Python JAVA

# %%
def returnFuc(data1, data2):
    return data1 + data2  # 함수는 return을 통해 값을 반환할 수 있음.:

# %%
result = returnFuc('data1', 'data2')  # 함수 호출, 인자 전달
print(result)
result = returnFuc(1, 2)  # 함수 호출, 인자 전달
print(result)
# Out:
# data1data2
# 3

# %% [markdown]
# ##### 용어
# - 인풋 (input), 인자(argument, parameter): 함수에 전달되는 값
